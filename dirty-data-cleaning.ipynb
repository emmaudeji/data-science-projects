# %%
import pandas as pd

# %%
df = pd.read_csv("dirty_instacart_sales.csv")

# %%
data = df.copy()

# %%
data.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='str')

# %%
data.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df["Quantity"].value_counts()
# Out:
# Quantity
# 5          2013
# 2          1974
# 4          1863
# 3          1849
# 1          1822
# UNKNOWN     171
# ERROR       170
# Name: count, dtype: int64

# %%
df["Quantity"].isna().sum()
# Out:
# np.int64(138)

# %%
# data["Quantity"] = pd.to_numeric(data["Quantity"])
# change each text to NAN

# data["Quantity"].value_counts()
data["Quantity"] = pd.to_numeric(data["Quantity"], errors= "coerce")

# %%
data["Quantity"].value_counts()
# Out:
# Quantity
# 5          2013
# 2          1974
# 4          1863
# 3          1849
# 1          1822
# UNKNOWN     171
# ERROR       170
# Name: count, dtype: int64

# %%
data["Quantity"].isna().sum()
# Out:
# np.int64(479)

# %%
mean_quantity = data["Quantity"].mean()
# data["Quantity"] = data["Quantity"].fillna(mean_quantity)
mean_quantity = int(mean_quantity)
mean_quantity
# Out:
# 3

# %%
 
mean_quantity = int(mean_quantity)

data["Quantity"] = data["Quantity"].fillna(mean_quantity)

# %%
mean_quantity
# Out:
# 3

# %%
data["Quantity"].value_counts()
# Out:
# Quantity
# 3.0    2328
# 5.0    2013
# 2.0    1974
# 4.0    1863
# 1.0    1822
# Name: count, dtype: int64

# %%
data["Quantity"].isna().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#   Transaction ID    Item  Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee       2.0            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake       4.0            3.0        12.0            Cash
# 2    TXN_4271903  Cookie       4.0            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad       2.0            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee       2.0            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
data["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0        2429
# 4.0        2331
# 2.0        1227
# 5.0        1204
# 1.0        1143
# 1.5        1133
# ERROR       190
# UNKNOWN     164
# Name: count, dtype: int64

# %%
data["Price Per Unit"] = pd.to_numeric(data["Price Per Unit"], errors="coerce")

# %%
data["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0    2096
# 4.0    2017
# 2.0    1069
# 5.0    1035
# 1.0     976
# 1.5     965
# Name: count, dtype: int64

# %%
mean_price = data["Price Per Unit"].mean()
# data["Price Per Unit"] = data["Price Per Unit"].fillna(data["Price Per Unit"].mean())
mean_price
# Out:
# np.float64(2.9532360872762933)

# %%
mean_price = int(mean_price)
mean_price
# Out:
# 2

# %%
data["Price Per Unit"] = data["Price Per Unit"].fillna(mean_price)

# %%
data["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0    2096
# 4.0    2017
# 2.0    1524
# 5.0    1035
# 1.0     976
# 1.5     965
# Name: count, dtype: int64

# %%
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0         4.0
# 1       TXN_4977031      Cake       4.0             3.0        12.0
# 2       TXN_4271903    Cookie       4.0             1.0       ERROR
# 3       TXN_7034554     Salad       2.0             5.0        10.0
# 4       TXN_3160411    Coffee       2.0             2.0         4.0
# ...             ...       ...       ...             ...         ...
# 9995    TXN_7672686    Coffee       2.0             2.0         4.0
# 9996    TXN_9659401       NaN       3.0             2.0         3.0
# 9997    TXN_5255387    Coffee       4.0             2.0         8.0
# 9998    TXN_7695629    Cookie       3.0             2.0         3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data["Total Spent"].value_counts()
# Out:
# Total Spent
# 8.0     1017
# 6.0      840
# 12.0     811
# 4.0      797
# 3.0      795
# 20.0     644
# 15.0     614
# 10.0     455
# 2.0      432
# 9.0      413
# 5.0      400
# 16.0     383
# 25.0     229
# 7.5      210
# 4.5      195
# 1.0      194
# 1.5      184
# Name: count, dtype: int64

# %%
data["Total Spent"] =  pd.to_numeric(data["Total Spent"], errors="coerce")

# %%
data["Total Spent"].value_counts()
# Out:
# Total Spent
# 8.0     1017
# 6.0      840
# 12.0     811
# 4.0      797
# 3.0      795
# 20.0     644
# 15.0     614
# 10.0     455
# 2.0      432
# 9.0      413
# 5.0      400
# 16.0     383
# 25.0     229
# 7.5      210
# 4.5      195
# 1.0      194
# 1.5      184
# Name: count, dtype: int64

# %%
mean_spent =int( data["Total Spent"].mean()
)

# %%
mean_spent
# Out:
# 8

# %%
data["Total Spent"] = data["Total Spent"].fillna(mean_spent)
# data["Total Spent"].isna().sum()

# %%
data["Total Spent"].isna().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          8.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date  Total  Spent
# 0     Credit Card  Takeaway       2023-09-08           4.0
# 1            Cash  In-store       2023-05-16          12.0
# 2     Credit Card  In-store       2023-07-19           8.0
# 3         UNKNOWN   UNKNOWN       2023-04-27          10.0
# 4  Digital Wallet  In-store       2023-06-11           4.0

# %%
data["Transaction Date"].value_counts()
# Out:
# Transaction Date
# UNKNOWN       159
# ERROR         142
# 2023-02-06     40
# 2023-06-16     40
# 2023-03-13     39
#              ...
# 2023-09-24     15
# 2023-07-30     15
# 2023-03-11     14
# 2023-07-22     14
# 2023-02-17     14
# Name: count, Length: 367, dtype: int64

# %%
import numpy as np
data["Transaction Date"] = data["Transaction Date"].replace(["UNKNOWN", "ERROR"], np.nan)

# %%
data["Transaction Date"].value_counts()
# Out:
# Transaction Date
# 2023-02-06    40
# 2023-06-16    40
# 2023-03-13    39
# 2023-07-21    39
# 2023-07-24    39
#               ..
# 2023-09-24    15
# 2023-07-30    15
# 2023-03-11    14
# 2023-07-22    14
# 2023-02-17    14
# Name: count, Length: 365, dtype: int64

# %%
data["Transaction Date"].isna().sum()
# Out:
# np.int64(460)

# %%
data["Transaction Date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
data["Transaction Date"] = pd.to_datetime(data["Transaction Date"], errors="coerce")
# errors="coerce" changes any non date equivakent vakue to NaT, equivalent to NaN

# %%
data["Transaction Date"].dtype
# Out:
# dtype('<M8[us]')

# %%
data["Transaction Date"].isna().sum()
# Out:
# np.int64(460)

# %%
data = data.dropna(subset=["Transaction Date"])

# %%
data.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          8.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date  Total  Spent
# 0     Credit Card  Takeaway       2023-09-08           4.0
# 1            Cash  In-store       2023-05-16          12.0
# 2     Credit Card  In-store       2023-07-19           8.0
# 3         UNKNOWN   UNKNOWN       2023-04-27          10.0
# 4  Digital Wallet  In-store       2023-06-11           4.0

# %%
data.drop(columns=['Total  Spent'], inplace=True)

# %%
data["Item"].isna().sum()
# Out:
# np.int64(315)

# %%
data["Item"].value_counts()
# Out:
# Item
# Juice       1124
# Coffee      1123
# Salad       1099
# Cake        1082
# Sandwich    1075
# Smoothie    1048
# Cookie      1035
# Tea         1027
# UNKNOWN      329
# ERROR        283
# Name: count, dtype: int64

# %%
data["Item"]=data["Item"].replace(["UNKNOWN", "ERROR"], np.nan )

# %%
data["Item"].value_counts()
# Out:
# Item
# Juice       1124
# Coffee      1123
# Salad       1099
# Cake        1082
# Sandwich    1075
# Smoothie    1048
# Cookie      1035
# Tea         1027
# Name: count, dtype: int64

# %%
data["Item"].isna().sum()
# Out:
# np.int64(927)

# %%
print(data.shape)
print(data["Item"].isna().sum())
# Out:
# (9540, 8)
# 927

# %%
data['Item']=data['Item'].dropna()
data['Item'].isna().sum()
# Out:
# np.int64(927)

# %%
data['Item'].isna().sum()
# Out:
# np.int64(927)

# %%
data = data.dropna(subset=['Item'])

# %%
data.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          8.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
data["Payment Method"].value_counts()
# Out:
# Payment Method
# Digital Wallet    1980
# Cash              1956
# Credit Card       1949
# ERROR              276
# UNKNOWN            249
# Name: count, dtype: int64

# %%
data["Payment Method"]=data["Payment Method"].replace(['ERROR','UNKNOWN'], np.nan)

# %%
data["Payment Method"] = data["Payment Method"].fillna('Missing')

# %%
data.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          8.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         Missing   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
data['Location'] = data['Location'].replace(['UNKNOWN','ERROR'], np.nan)

# %%
# data['Location'] = data['Location'].fillna()
df["Location"].value_counts()
# Out:
# Location
# Takeaway    3022
# In-store    3017
# ERROR        358
# UNKNOWN      338
# Name: count, dtype: int64

# %%
data["Location"].isna().sum()
# Out:
# np.int64(3423)

# %%
data["Location"] = data["Location"].fillna('Missing')

# %%
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          8.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9993    TXN_4766549  Smoothie       2.0             4.0          8.0
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             NaN          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
data.isna().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
data.shape
# Out:
# (8613, 8)
